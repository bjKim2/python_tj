# %%
#store_list > tr:nth-child(1) > td.td_shop

# %%
# !pip install certifi

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd

# %%
url = 'https://paikdabang.com/store/'
page = urlopen(url)
soup = BeautifulSoup(page, 'html.parser')

# %%
print(soup.select("#store_list > tr > td.td_shop"))
# Out:
# []

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
# Chrome Browser와 Chrome Driver Version 확인하기

chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.get('https://paikdabang.com/store/')
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache

# %%
import time

# %%
page_source = driver.page_source 
soup = BeautifulSoup(page_source, "html.parser")

# %%
stores= soup.select('#store_list > tr > td')

# %%
st_reg = []
st_name = []
st_add = []



    
print(st_name)
# //*[@id="pagination"]/li[5]/a

for i in range(1,111):
    if(i == 3):
        i =  4
    elif(i >= 4):   
        i= 6

    xpath = '//*[@id="pagination"]/li['+ str(i)+']/a'
    
    page = driver.find_element(By.XPATH,xpath).click()

    time.sleep(2)

    page_source = driver.page_source 
    soup = BeautifulSoup(page_source, "html.parser")    
    stores= soup.select('#store_list > tr > td')

    index = len(stores)
    num = int(index / 6)
    mul6 = 0
    
    for i in range(0,num):
        mul6 = i*6
        st_reg.append(stores[mul6].string)
        st_name.append(stores[1 + mul6].string)
        st_add.append(stores[2 + mul6].string)

    time.sleep(1)

print(len(st_reg),'\n',st_reg)
# Out:
# []
# 1095
# ...

# %%
st_name[1:10]
# Out:
# ['부평동아점',
#  '제주합동청사점',
#  '시흥능곡장현점',
#  '개롱역점',
#  '원주간현점',
#  '광주하남점',
#  '상계보람점',
#  '충남부여점',
#  '장안뉴시티점']

# %%
len(st_name)
# Out:
# 1095

# %%
st_name[-10:]
# Out:
# ['용인동백쥬네브점',
#  '신림역2호점',
#  '청량리역점',
#  '총신대입구역점',
#  '동탄솔빛나루점',
#  '신대방삼거리점',
#  '충남대병원점',
#  '태평로점',
#  '구미상모점',
#  '천안불당중앙점']

# %%
st_name[-20:-10]
# Out:
# ['망원시장점',
#  '수원역전시장점',
#  '화성수원대점',
#  '시흥월곶점',
#  '남양주덕소점',
#  '양산터미널점',
#  '군산수송점',
#  '대전역점',
#  '분당미금역천사점',
#  '울산남목초교점']

# %%
paik_df = pd.DataFrame(data=st_name,columns=['매장명'])

paik_df['지역'] = pd.Series(st_reg)
paik_df['주소'] = pd.Series(st_add)

# %%
paik_df
# Out:
#           매장명     지역                                     주소
# 0      주안북부역점  인천광역시             인천 미추홀구 주안동 25-65  (5호,6호)
# 1       부평동아점  인천광역시  인천 부평구 부평문화로 55 (부평동, 와이디타워) 1층, 102호
# 2     제주합동청사점    제주도                     제주도 제주시 도남동 663-12
# 3     시흥능곡장현점    경기도                        경기 시흥시 능곡번영길 25
# 4        개롱역점  서울특별시        서울 송파구 가락동 166-2 에스케이허브파크 113호
# ...       ...    ...                                    ...
# 1090  신대방삼거리점  서울특별시                     서울특별시 동작구 국사봉1길 28
# 1091   충남대병원점  대전광역시                   대전광역시 중구 계룡로920번길 36
# 1092     태평로점  서울특별시                     서울시 중구 세종대로 82, 1층
# 1093    구미상모점   경상북도                   경상북도 구미시 상사서로 77, 1층
# 1094  천안불당중앙점   충청남도      충청남도 천안시 서북구 검은들3길 58, 매가클래스블루 1층
#
# [1095 rows x 3 columns]

# %%
paik_df.to_csv('../Data/paik.csv',encoding='utf-8' ,index=False)

# %% [markdown]
# ---
# # 커피빈 크롤링

# %%
chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.get('https://www.coffeebeankorea.com/store/store.asp')
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache

# %%
xpath = '//*[@id="region_srh"]'
    
page = driver.find_element(By.XPATH,xpath).click()

# %%
from urllib import parse

# %%
a = parse.quote("�쒖슱")

# driver.execute_script('storeLocal')
driver.execute_script('storeLocal2(\'寃쎄린\')')
# driver.execute_script('storeLocal')

# %%
print(type(a))
print(a)
# Out:
# <class 'str'>
# %EF%BF%BD%EC%92%96%EC%8A%B1

# %%
driver.execute_script('storeLocal2','서울')

# %%
driver.execute_script('storeLocal("경기")')

# %%
# //*[@id="store_list"]/tr[1]/td[3]
xpath = '//*[@id="store_list"]/tr[1]'
stores = driver.find_element(By.XPATH, xpath) # '' 홑따옴표만 가능!

# %%
store = stores.find_elements(By.TAG_NAME,'td')

# %%
print(store[1].accessible_name)
print(store[2].accessible_name)
# Out:
# 주안북부역점
# 인천 미추홀구 주안동 25-65 (5호,6호)

# %%
# //*[@id="store_list"]/tr[3]/td[3]
# //*[@id="store_list"]/tr[5]/td[3]
# //*[@id="store_list"]/tr[19]/td[3]
