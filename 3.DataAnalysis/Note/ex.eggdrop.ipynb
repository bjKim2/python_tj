# %%
import pandas as pd

# %%
egg = pd.read_csv("../Data/eggdrop.csv")
egg.head()
# Out:
#        지점명                              주소
# 0  강릉교동택지점  강릉 교동 솔올로 5번길 55 청호아넥스빌딩 1층 6호
# 1    강릉중앙점               강원 강릉시 경강로 2092-1
# 2     강원대점                강원 춘천시 서부대성로 239
# 3    동해천곡점        강원 동해시 천곡동 850외 1필지 104호
# 4   속초엑스포점                강원 속초시 엑스포로1길 39

# %%
egg.주소[0].split()[0]
# Out:
# '강릉'

# %%
add = []
for region in egg.주소:
    add.append(region.split()[0])
add
# Out:
# ['강릉',
#  '강원',
#  '강원',
#  '강원',
#  '강원',
#  '강원',
#  '강원도',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기도',
#  '경기도',
#  '경기',
#  '경기도',
#  '경기',
#  '경기도',
#  '경기',
#  '경기',
#  '경기도',
#  '경기',
#  '경기',
#  '경기도',
#  '경기',
#  '경기',
#  '경기도',
#  '경기',
#  '경기도',
#  '경기도',
#  '경기도',
#  '경기',
#  '경기도',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기도',
#  '경기도',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기도',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기',
#  '경기도',
#  '경기',
#  '경기도',
#  '경기',
#  '경기도',
#  '경기',
#  '경기',
#  '경기',
#  '경남',
#  '경남',
#  '경남',
#  '경상남도',
#  '경남',
#  '경남',
#  '경남',
#  '경상남도',
#  '경남',
#  '경남',
#  '경남',
#  '경남',
#  '경북',
#  '경북',
#  '경북',
#  '경상북도',
#  '경북',
#  '광주광역시',
#  '광주',
#  '광주',
#  '광주',
#  '광주',
#  '대구',
#  '대구',
#  '대구광역시',
#  '대구',
#  '대구',
#  '대구',
#  '대구광역시',
#  '대구광역시',
#  '대전광역시',
#  '대전',
#  '대전',
#  '부산',
#  '부산광역시',
#  '부산광역시',
#  '부산',
#  '부산',
#  '부산광역시',
#  '부산',
#  '부산광역시',
#  '부산',
#  '부산광역시',
#  '부산',
#  '부산시',
#  '부산',
#  '부산',
#  '부산시',
#  '서울',
#  '서울',
#  '서울시',
#  '서울',
#  '서울특별시',
#  '서울특별시',
#  '서울',
#  '서울',
#  '서울',
#  '서울시',
#  '서울',
#  '서울',
#  '서울',
#  '서울',
#  '서울시',
#  '서울특별시',
#  '서울',
#  '서울특별시',
#  '서울특별시',
#  '서울',
#  '서울',
#  '서울',
#  '서울',
#  '서울',
#  '서울',
#  '서울',
#  '서울시',
#  '서울',
#  '서울시',
#  '서울시',
#  '서울',
#  '서울',
#  '서울특별시',
#  '서울',
#  '경기',
#  '서울',
#  '서울시',
#  '서울',
#  '서울시',
#  '서울',
#  '서울',
#  '서울',
#  '서울',
#  '서울',
#  '서울',
#  '서울',
#  '부산',
#  '서울',
#  '서울시',
#  '대전광역시',
#  '서울특별시',
#  '서울시',
#  '서울',
#  '서울',
#  '서울',
#  '서울',
#  '세종시',
#  '세종시',
#  '세종특별자치시',
#  '울산',
#  '울산',
#  '울산시',
#  '울산',
#  '울산',
#  '울산',
#  '인천',
#  '인천',
#  '인천광역시',
#  '인천',
#  '인천광역시',
#  '인천시',
#  '인천광역시',
#  '인천',
#  '인천',
#  '인천',
#  '인천광역시',
#  '인천',
#  '전남',
#  '전남',
#  '전남',
#  '전남',
#  '전남',
#  '전남',
#  '전북',
#  '전북',
#  '전북',
#  '전라북도',
#  '전라북도',
#  '전북',
#  '전북',
#  '전북',
#  '제주특별자치도',
#  '제주',
#  '제주',
#  '제주',
#  '제주특별자치도',
#  '충남',
#  '충남',
#  '충남',
#  '충남',
#  '충남',
#  '충남',
#  '충청남도',
#  '충청남도',
#  '충남남도',
#  '충남',
#  '충청북도',
#  '충북',
#  '충청북도',
#  '충북']

# %%
egg_sub = egg.iloc[199:,:]

# %%
sum(egg_sub['주소'] == '충남남도 천안시 동남구 청수4로18, 103호')
# Out:
# 1

# %%
egg_sub.loc[egg_sub['주소'] == '충남남도 천안시 동남구 청수4로18, 103호','주소'] = '청당동 491'
# Out:
# /Users/tj/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/tj/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
import urllib.request

lats = []
lngs = []


for address in egg_sub['주소']:
    
    client_id = "84zdgtnty4"
    client_secret= "T9d39jjdBNbj2YsxiEgdBSyzJisfDOVTgeYLkHBq"

    encText = urllib.parse.quote(address)
    url = "https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode?query=" + encText
    request = urllib.request.Request(url)
    request.add_header("X-NCP-APIGW-API-KEY-ID",client_id)
    request.add_header("X-NCP-APIGW-API-KEY",client_secret)

    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if rescode == 200:
        response_body = response.read()
        enText = response_body.decode('utf-8')
    else:
        print("Error Code:" + rescode)

    import json
    data1 = json.loads(enText)

    if( len(data1['addresses'] ) == 0):
        print(address)
    lngs.append(data1['addresses'][0]['x'])
    lats.append(data1['addresses'][0]['y'])

# %%
len(lngs)
# Out:
# 34

# %%
lngs
# Out:
# ['126.6579170',
#  '127.6975329',
#  '127.4841347',
#  '127.5461465',
#  '127.5168796',
#  '127.7440497',
#  '126.3842810',
#  '126.7175037',
#  '126.9386415',
#  '126.9723575',
#  '127.1278732',
#  '127.1087689',
#  '127.1457118',
#  '127.1340538',
#  '127.1311813',
#  '126.5614808',
#  '126.4908824',
#  '126.4959513',
#  '126.5799027',
#  '126.5284354',
#  '127.2427896',
#  '126.6299859',
#  '126.4490562',
#  '127.0548290',
#  '127.0145219',
#  '127.1413382',
#  '127.1293358',
#  '127.1076283',
#  '127.1527904',
#  '127.1573679',
#  '127.4296910',
#  '127.3320623',
#  '127.4976071',
#  '127.4274454']

# %%
egg_sub['lat'] = lats
egg_sub['lng'] = lngs
# Out:
# /var/folders/r9/905wglgd76v1f_n1q9jw68rr0000gn/T/ipykernel_13842/927980832.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   egg_sub['lat'] = lats
# /var/folders/r9/905wglgd76v1f_n1q9jw68rr0000gn/T/ipykernel_13842/927980832.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   egg_sub['lng'] = lngs

# %%
egg_sub
# Out:
#              지점명                                주소         lat          lng
# 199     현대아울렛송도점  인천 연수구 송도국제대로 123 현대프리미엄 아울렛 송도점  37.3816291  126.6579170
# 200        광양중마점                     전남 광양시 공영로 78  34.9356914  127.6975329
# 201         순천대점                    전남 순천시 중앙로 268  34.9696228  127.4841347
# 202        순천신대점                 전남 순천시 해룡면 향매로 59  34.9346455  127.5461465
# 203        순천연향점                    전남 순천시 연향3로 11  34.9509150  127.5168796
# 204      여수해양공원점              전남 여수시 이순신 광장로 191-3  34.7386161  127.7440497
# 205       차없는거리점                 전남 목포시 영산로75번길 22  34.7910693  126.3842810
# 43         문래GS타워점                     서울 영등포구 문래동3가 84-2  37.520659
# 44            문정역점     서울 송파구 송파대로 167 테라타워 B동 지하1층 G124호  37.484835
# 45            보라매점                      서울 동작구 보라매로 5가길 7  37.491953
# 46            상수역점                          서울 마포구 독막로 77  37.547936
# 47          상암DMC점                  서울 마포구 상암동1605 누리꿈스퀘어  37.579413
# 48       서울가재울뉴타운점                       서울 서대문구 거북골로 100  37.576020
#
#            lng
# 0   128.595225
# 1   128.637196
# 2   128.525717
# 3   128.697201
# 4   128.563326
# 5   127.339772
# 6   127.388979
# 7   127.398690
# 8   129.063490
# 9   129.034045
# 10  129.086752
# 11  129.007218
# 12  129.214784
# 13  129.103465
# 14  129.060656
# 15  129.055377
# 16  129.131583
# 17  129.116702
# 18  129.177678
# 19  129.063592
# 20  129.175533
# 21  128.965333
# 22  129.158459
# 23  126.882800
# 24  127.124962
# 25  126.887684
# 26  127.021980
# 27  127.025604
# 28  127.031179
# 29  127.029971
# 30  127.052738
# 31  127.097264
# 32  126.978969
# 33  126.896160
# 34  127.022397
# 35  126.944133
# 36  127.076574
# 37  127.001898
# 38  127.006609
# 39  126.828637
# 40  126.948980
# 41  127.090385
# 42  126.863900
# 43  126.889928
# 44  127.121039
# 45  126.924968
# 46  126.922102
# 47  126.890424
# 48  126.917491

# %%
tmp = glob("../Data/egg/*.csv")
tmp
tmps = []
for path in tmp:
    temp = pd.read_csv(path)
    temp.columns = list(egg_sub.columns)
    tmps.append(temp)

df = pd.concat(tmps)

# %%
df
# Out:
#         지점명                             주소        lat         lng
# 0   강릉교동택지점              강원도 강릉시 교동 1882-4  37.763897  128.877560
# 1     강릉중앙점              강원 강릉시 경강로 2092-1  37.754457  128.896058
# 2      강원대점               강원 춘천시 서부대성로 239  37.872923  127.744483
# 3     동해천곡점       강원 동해시 천곡동 850외 1필지 104호  37.522828  129.114622
# 4    속초엑스포점               강원 속초시 엑스포로1길 39  38.190472  128.585710
# ..      ...                            ...        ...         ...
# 28   천안터미널점           충남 천안시 동남구 신부동 462-5  36.818649  127.157368
# 29   가경터미널점           충청북도 청주시 흥덕구 강서로 118  36.624756  127.429691
# 30    청주오송점  충북 청주시 흥덕구 오송읍 오송생명로 210 101호  36.630250  127.332062
# 31    청주율량점       충청북도 청주시 청원구 주성로279번길 22  36.671327  127.497607
# 32  청주지웰시티점         충북 청주시 흥덕구 복대동 545-8번지  36.640607  127.427445
#
# [233 rows x 4 columns]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=233, step=1)

# %%
len(df)
# Out:
# 233

# %%
import folium 

map = folium.Map(
    location = [37.5502, 126.982],
    zoom_start= 11,
    # tiles = 'Stamen Toner'
)



for n in range(len(df)):
    
    
    folium.Marker(
        [df.lat[n], df.lng[n]],
        popup=df.지점명[n],
        icon=folium.Icon(icon='star',color = 'blue')
    ).add_to(map)
    folium.CircleMarker(
        [df.lat[n], df.lng[n]],
        popup=df.지점명[n],
        color = 'blue',
        fill = True,
        fill_color = 'blue',
        fill_opacity = 0.3,
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f6c292d42d807d3fe16828b7aa8bcc9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f6c292d42d807d3fe16828b7aa8bcc9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0f6c292d42d807d3fe16828b7aa8bcc9 = L.map(
#                 &quot;map_0f6c292d42d807d3fe16828b7aa8bcc9&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62d4040b6ccaa695092ece5a3d7e5557 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0f6c292d42d807d3fe16828b7aa8bcc9);
#
#
#             var marker_b8aa7692c32b1de9af2eb007de6bd11e = L.marker(
#                 [37.7638966, 128.8775597],
#                 {}
#             ).addTo(map_0f6c292d42d807d3fe16828b7aa8bcc9);
#
#
#             var icon_7fad7ee099466fe5f29483d45414eb5a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b8aa7692c32b1de9af2eb007de6bd11e.setIcon(icon_7fad7ee099466fe5f29483d45414eb5a);
#
#
#         var popup_53f8fd7f0fa05c5244930903dd997539 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8827bace6f2d64b1038a72674e136a7f = $(`&lt;div id=&quot;html_8827bace6f2d64b1038a72674e136a7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강릉교동택지점&lt;/div&gt;`)[0];
#             popup_53f8fd7f0fa05c5244930903dd997539.setContent(html_8827bace6f2d64b1038a72674e136a7f);
#
#
#         marker_b8aa7692c32b1de9af2eb007de6bd11e.bindPopup(popup_53f8fd7f0fa05c5244930903dd997539)
#         ;
#
#
#
#
#             var circle_marker_f0f7f702cea7aee3200b2da6a041303b = L.circleMarker(
#                 [37.7638966, 128.8775597],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0f6c292d42d807d3fe16828b7aa8bcc9);
#
#
#         var popup_eb6a67ccf17155a35c9fad233cf23327 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_615ee7661723104be3202067086c460f = $(`&lt;div id=&quot;html_615ee7661723104be3202067086c460f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강릉교동택지점&lt;/div&gt;`)[0];
#             popup_eb6a67ccf17155a35c9fad233cf23327.setContent(html_615ee7661723104be3202067086c460f);
#
#
#         circle_marker_f0f7f702cea7aee3200b2da6a041303b.bindPopup(popup_eb6a67ccf17155a35c9fad233cf23327)
#         ;
#
#
#
#
#             var marker_86a07f4049ac0123fa0fb22a38df038c = L.marker(
#                 [37.7544566, 128.8960582],
#                 {}
#             ).addTo(map_0f6c292d42d807d3fe16828b7aa8bcc9);
#
#
#             var icon_6ca95fe2feabbec364e3314822615752 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_86a07f4049ac0123fa0fb22a38df038c.setIcon(icon_6ca95fe2feabbec364e3314822615752);
#
#
#         var popup_ceeb26ef08fbbd590c9d7cd1c41b0995 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7e3dc7aa3619cc29a79ca001bd158881 = $(`&lt;div id=&quot;html_7e3dc7aa3619cc29a79ca001bd158881&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강릉중앙점&lt;/div&gt;`)[0];
#             popup_ceeb26ef08fbbd590c9d7cd1c41b0995.setContent(html_7e3dc7aa3619cc29a79ca001bd158881);
#
#
#         marker_86a07f4049ac0123fa0fb22a38df038c.bindPopup(popup_ceeb26ef08fbbd590c9d7cd1c41b0995)
#         ;
#
#
#
#
#             var circle_marker_d27f760aa08f467bfdf12c3a5465cbeb = L.circleMarker(
#                 [37.7544566, 128.8960582],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addT
